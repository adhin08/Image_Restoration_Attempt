# %% [markdown]
# <a href="https://colab.research.google.com/github/adhin08/Image_Restoration_Attempt/blob/main/Image_restoration_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run image_restoration_project_colab.py
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 59.6MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.70MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.6MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.45MB/s]
# Epoch [1/3], Loss: 0.0241
# Epoch [2/3], Loss: 0.0173
# Epoch [3/3], Loss: 0.0153
